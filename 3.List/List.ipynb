# %%
# kita sekarang memulai list. List itu ibarat loker , di mana di tiap-tiap loker kita bisa menyimpan barang-barang kita
# nah kita bisa mengambil barang dalam loker itu sesuai nomornya (loker ke berapa) 
# catatan dalam program perhitungan itu dimulai dari 0 bukan satu 
# jadi kalau kita punya barang di loker ke satu bararti dia urutan ke 0 dalam program komputer.

# %%
# Membuat List
database_ai = ["Jarvis", 1.0, "Jawa Tengah", "Online"]

# Menampilkan seluruh isi lemari
print(database_ai)
# Out:
# ['Jarvis', 1.0, 'Jawa Tengah', 'Online']
