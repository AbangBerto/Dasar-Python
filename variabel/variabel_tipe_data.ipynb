# %% [markdown]
# # Dasar belajar pyhton, tipe data dan variabel

# %%
# di dalam python kita tidak perlu meluliskan tipe data saat mendeklarasi variabel contohnya seperti di bawah ini 
nama = "berto"
angka = 5
desimal = 0.5

print(nama, angka, desimal)
# Out:
# berto 5 (0, 5)

# %%
# nah dari output di atas kalian lihat hanya keluar output dari variabel-variabel yang kita buat sebelumnya 
#lalu bagimana? jika kita ingin mengetahui tipe data variabel tersebut di dalam python? caranya seperti di bawah ini.

print(type (nama))
print(type (angka))
print(type (desimal))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'tuple'>

# %%
# nah dalam output di atas kita tau tipe data variabel-variabel yang sebelumnya kita buat. 
# <class 'str'> -> Artinya String (Teks).
# <class 'float'> -> Artinya Float (Angka Desimal).
# <class 'int'> -> Artinya Integer (Angka Bulat).

# %%
# nama_ai = "jarvis"
# versi = 1.0
# kecepatan = 99.5

# print("Nama AI : " , nama_ai)
# print("Versi : " , versi)
# print("Kecepatan : " , kecepatan)
# Out:
# Nama AI :  jarvis
# Versi :  1.0
# Kecepatan :  99.5

# %%
#dalam program kolom ke 5 di atas varibaelnya nama masih kita tentukan di awal. Sekarang kita ingin program bertanya kepada kita sebelum menginputkan nama.

# %%
# nama_ai = input ("Nama AI : ")
# versi = float (input ("versi : "))
# kecepatan = float (input("kecepatan : "))

# print("Versi : " , versi)
# print("Kecepatan : " , kecepatan)
# Out:
# Nama AI :  Jarvis
# versi :  1.0
# kecepatan :  99
# Versi :  1.0
# Kecepatan :  99.0

# %%
#bagaimana jika kita ingin menambah versi dari ai itu?
nama_ai = input ("Nama AI : ")
versi = float (input ("versi : "))
kecepatan = float (input("kecepatan : "))

print("Versi : " , versi)
print("Kecepatan : " , kecepatan)

versi_baru = versi + 1.0 
print("sedang menginstall pembaruan.....")
print("Versi AI anda sekarang menjadi : ", versi_baru)
# Out:
# Nama AI :  Jarvis
# versi :  1.0
# kecepatan :  99
# Versi :  1.0
# Kecepatan :  99.0
# sedang menginstall pembaruan.....
# Versi AI anda sekarang menjadi :  2.0
